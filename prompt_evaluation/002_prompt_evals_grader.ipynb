# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Extract AWS Region from S3 Bucket ARN\n\nHere's a solution to extract the AWS region from an S3 bucket ARN:\n\n```python\nimport re\n\ndef extract_region_from_s3_arn(arn):\n    \"\"\"\n    Extract AWS region from an S3 bucket ARN.\n    \n    S3 bucket ARNs don't inherently contain region information,\n    but regions are often encoded in the bucket name itself.\n    \n    Args:\n        arn: S3 bucket ARN (e.g., \"arn:aws:s3:::my-bucket-us-east-1\")\n    \n    Returns:\n        Region string if found, None otherwise\n    \"\"\"\n    # Extract bucket name from ARN\n    match = re.search(r'arn:aws:s3:::([a-z0-9.-]+)$', arn)\n    if not match:\n        return None\n    \n    bucket_name = match.group(1)\n    \n    # List of AWS regions\n    regions = [\n        'us-east-1', 'us-east-2', 'us-west-1', 'us-west-2',\n        'af-south-1', 'ap-east-1', 'ap-south-1', 'ap-northeast-1',\n        'ap-northeast-2', 'ap-northeast-3', 'ap-southeast-1',\n        'ap-southeast-2', 'ca-central-1', 'eu-central-1',\n        'eu-north-1', 'eu-south-1', 'eu-west-1', 'eu-west-2',\n        'eu-west-3', 'me-south-1', 'sa-east-1'\n    ]\n    \n    # Search for region in bucket name\n    for region in regions:\n        if region in bucket_name:\n            return region\n    \n    return None\n\n\n# Test cases\ntest_arns = [\n    \"arn:aws:s3:::my-bucket-us-east-1\",\n    \"arn:aws:s3:::data-eu-west-1-prod\",\n    \"arn:aws:s3:::ap-southeast-2-logs\",\n    \"arn:aws:s3:::my-bucket\"\n]\n\nfor arn in test_arns:\n    region = extract_region_from_s3_arn(arn)\n    print(f\"{arn} -> {region}\")\n```\n\n**Output:**\n```\narn:aws:s3:::my-bucket-us-east-1 -> us-east-1\narn:aws:s3:::data-eu-west-1-prod -> eu-west-1\narn:aws:s3:::ap-southeast-2-logs -> ap-southeast-2\narn:aws:s3:::my-bucket -> None\n```\n\n## Key Points:\n\n1. **S3 ARN Format**: `arn:aws:s3:::bucket-name` (no region in the ARN itself)\n2. **Region Detection**: Regions are extracted from the bucket name, not the ARN structure\n3. **Returns**: The region code if found, `None` if not detected\n4. **Limitation**: This works only if the bucket name contains the region code\n\nFor production use, you might want to query AWS to get the actual bucket region using `boto3`:\n\n```python\nimport boto3\n\ndef get_s3_bucket_region(bucket_name):\n    s3 = boto3.client('s3')\n    response = s3.get_bucket_location(Bucket=bucket_name)\n    return response['LocationConstraint']\n```",
#     "test_case": {
#       "task": "Extract the AWS region from an S3 bucket ARN (e.g., arn:aws:s3:::my-bucket-us-east-1)",
#       "format": "regex"
#     },
#     "score": 4,
#     "reasoning": "The solution correctly recognizes that S3 ARNs lack region information, but the proposed extraction method is unreliable heuristic-based pattern matching rather than a real solution. While the boto3 recommendation is correct, it's presented as secondary rather than primary. The code works for artificially crafted examples but would fail in production. The regex validation is appropriate, but the region extraction logic conflates bucket naming conventions with actual region determination."
#   },
#   {
#     "output": "# CloudFormation SQS Queue Template\n\nHere's a JSON CloudFormation template that creates an SQS queue with a 5-minute visibility timeout:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template to create an SQS queue with 5-minute visibility timeout\",\n  \"Resources\": {\n    \"MyQueue\": {\n      \"Type\": \"AWS::SQS::Queue\",\n      \"Properties\": {\n        \"QueueName\": \"my-sqs-queue\",\n        \"VisibilityTimeout\": 300,\n        \"MessageRetentionPeriod\": 1209600,\n        \"ReceiveMessageWaitTimeSeconds\": 0\n      }\n    }\n  },\n  \"Outputs\": {\n    \"QueueURL\": {\n      \"Description\": \"URL of the SQS Queue\",\n      \"Value\": {\n        \"Ref\": \"MyQueue\"\n      }\n    },\n    \"QueueArn\": {\n      \"Description\": \"ARN of the SQS Queue\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyQueue\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"QueueName\": {\n      \"Description\": \"Name of the SQS Queue\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyQueue\",\n          \"QueueName\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n| Property | Value | Description |\n|----------|-------|-------------|\n| **VisibilityTimeout** | 300 | 5 minutes in seconds (300 seconds = 5 minutes) |\n| **QueueName** | my-sqs-queue | Name of the queue (optional) |\n| **MessageRetentionPeriod** | 1209600 | 14 days in seconds (default max retention) |\n| **ReceiveMessageWaitTimeSeconds** | 0 | Short polling (set to 20 for long polling) |\n\n## To Deploy:\n\n```bash\naws cloudformation create-stack \\\n  --stack-name my-sqs-stack \\\n  --template-body file://template.json\n```\n\nThe visibility timeout of 300 seconds ensures that messages are hidden for 5 minutes after being received by a consumer, allowing time for processing before the message becomes visible again.",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template that defines an SQS queue with a 5-minute visibility timeout",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the core requirement with proper syntax and converts 5 minutes to the correct 300-second value. The template is valid and would deploy successfully. However, it includes extra properties beyond the stated requirement, and the QueueName property introduces unnecessary constraints. The documentation is clear but includes optional properties as if they're essential. For a minimal, production-ready solution, the template should be simplified to focus on the visibility timeout requirement."
#   },
#   {
#     "output": "# AWS IAM Role Name Validator\n\nHere's a comprehensive solution with validation function and tests:\n\n```python\nimport re\n\ndef validate_iam_role_name(role_name: str) -> tuple[bool, str]:\n    \"\"\"\n    Validates an AWS IAM role name according to AWS naming conventions.\n    \n    AWS IAM Role Name Requirements:\n    - Must contain only alphanumeric characters (a-z, A-Z, 0-9), hyphens (-), and underscores (_)\n    - Maximum length: 64 characters\n    - Minimum length: 1 character (implicit from AWS)\n    \n    Args:\n        role_name (str): The IAM role name to validate\n        \n    Returns:\n        tuple[bool, str]: (is_valid, message)\n            - is_valid: True if the role name is valid, False otherwise\n            - message: Descriptive message about validation result\n    \"\"\"\n    \n    # Check if input is a string\n    if not isinstance(role_name, str):\n        return False, \"Role name must be a string\"\n    \n    # Check if role name is empty\n    if not role_name:\n        return False, \"Role name cannot be empty\"\n    \n    # Check maximum length (64 characters)\n    if len(role_name) > 64:\n        return False, f\"Role name exceeds maximum length of 64 characters (current: {len(role_name)})\"\n    \n    # Check for valid characters (alphanumeric, hyphens, underscores)\n    # Pattern: ^[a-zA-Z0-9_-]+$\n    if not re.match(r'^[a-zA-Z0-9_-]+$', role_name):\n        return False, \"Role name contains invalid characters. Only alphanumeric characters, hyphens (-), and underscores (_) are allowed\"\n    \n    return True, \"Role name is valid\"\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid cases\n        (\"my-role\", True),\n        (\"MyRole\", True),\n        (\"my_role\", True),\n        (\"my-role_123\", True),\n        (\"123\", True),\n        (\"a\", True),\n        (\"MyRole_Dev-123\", True),\n        (\"A\" * 64, True),  # Exactly 64 characters\n        \n        # Invalid cases\n        (\"\", False),  # Empty\n        (\"my role\", False),  # Space not allowed\n        (\"my.role\", False),  # Dot not allowed\n        (\"my@role\", False),  # @ not allowed\n        (\"my*role\", False),  # * not allowed\n        (\"my/role\", False),  # / not allowed\n        (\"A\" * 65, False),  # Exceeds 64 characters\n        (\"my:role\", False),  # Colon not allowed\n        (\"my role!\", False),  # Multiple invalid characters\n        (123, False),  # Not a string\n        (None, False),  # None type\n    ]\n    \n    print(\"AWS IAM Role Name Validation Tests\")\n    print(\"=\" * 60)\n    \n    for role_name, expected_valid in test_cases:\n        is_valid, message = validate_iam_role_name(role_name)\n        status = \"\u2713 PASS\" if is_valid == expected_valid else \"\u2717 FAIL\"\n        \n        print(f\"{status} | Input: {repr(role_name):<30} | {message}\")\n    \n    print(\"\\n\" + \"=\" * 60)\n    print(\"\\nInteractive Test:\")\n    print(\"-\" * 60)\n    \n    # Interactive examples\n    interactive_tests = [\n        \"my-prod-role\",\n        \"Lambda_Execution_Role\",\n        \"invalid@role\",\n        \"a\" * 100,\n    ]\n    \n    for role in interactive_tests:\n        is_valid, message = validate_iam_role_name(role)\n        result = \"\u2713 Valid\" if is_valid else \"\u2717 Invalid\"\n        print(f\"{result}: {role}\")\n        print(f\"  \u2514\u2500 {message}\\n",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS IAM role name according to AWS naming conventions (alphanumeric, hyphens, underscores, max 64 characters)",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution demonstrates solid understanding of the validation requirements and provides correct core logic. The regex pattern, length checking, and type validation are all appropriate. However, the incomplete code with a syntax error significantly impacts usability. The type hint compatibility issue affects broader Python version support. These are relatively minor issues that could be quickly fixed, but they prevent the solution from being production-ready as presented."
#   }
# ]
